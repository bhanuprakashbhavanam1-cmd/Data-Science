# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# printing the variable x
x=18
print(x)
# Out:
# 18

# %%
# Performing substraction of two int variables
x=29
y=30
print(x-y)
# Out:
# -1

# %%
# Performing addition of two int variables
x=39
y=29
print(x+y)
# Out:
# 68

# %%
# Printing different data types and its values
a=29
b=37.34
name='data'
print(a)
print(b)
print(name)
print(type(a),type(b),type(name))
# Out:
# 29
# 37.34
# data
# <class 'int'> <class 'float'> <class 'str'>

# %%
a=40
b=20.34
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 40
# 20.34
# <class 'int'>
# <class 'float'>

# %%
a=22
b=30.11
name='jayanth reddy'
print(a)
print(b)
print(name)
print(type(a))
print(type(b))
print(type(name))
# Out:
# 22
# 30.11
# jayanth reddy
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a=10.09
b=23.33
c=a-b
d=a*b
e=a/b
print(c)
print(d)
print(e)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# -13.239999999999998
# 235.39969999999997
# 0.4324903557651093
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
a=10.09
b=23
c=a-b
d=a*b
e=a/b
print(c)
print(d)
print(e)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# -12.91
# 232.07
# 0.43869565217391304
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x='jayanth'
a=10.09
b=23
c=a-b
d=a*b
e=a/b
print(x)
print(a)
print(b)
print(c)
print(d)
print(e)
print(type(x))
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# jayanth
# 10.09
# 23
# -12.91
# 232.07
# 0.43869565217391304
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
type(5+9j)
# Out:
# complex

# %%
a=2+3j
a.real
# Out:
# 2.0

# %%
a.imag
# Out:
# 3.0

# %%
x=4+5j
print(type(x))
print(x.real)
print(x.imag)
# Out:
# <class 'complex'>
# 4.0
# 5.0

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text)
# Out:
# Edukron Data Science and Data Engineer Batch 2026

# %% [markdown]
# Write the indexing expression to print *"Edukron"*?

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[0:7])
print(Python_text[-49:-42])
# Out:
# Edukron
# Edukron

# %% [markdown]
# Write the indexing expression to print *"Data"* (first occurrence).

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[8:12])
print(Python_text[-41:-37])
# Out:
# Data
# Data

# %% [markdown]
# Write the indexing expression to print *"Science"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[13:20])
print(Python_text[-36:-29])
# Out:
# Science
# Science

# %% [markdown]
# Write the indexing expression to print *"and"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[21:24])
print(Python_text[-28:-25])
# Out:
# and
# and

# %% [markdown]
# Write the indexing expression to print *"Data Engineering"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[25:38])
print(Python_text[-24:-11])
# Out:
# Data Engineer
# Data Engineer

# %% [markdown]
# Write the indexing expression to print *"Engineering"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[30:38])
print(Python_text[-19:-11])
# Out:
# Engineer
# Engineer

# %% [markdown]
# Write the indexing expression to print *"Batch"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[39:44])
# Out:
# Batch

# %% [markdown]
# Write the indexing expression to print *"2026"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[45:51])
print(Python_text[-4:])
# Out:
# 2026
# 2026

# %% [markdown]
# Write the indexing expression to print *"Science and Data"*.

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[13:29])
print(Python_text[-36:-20])
# Out:
# Science and Data
# Science and Data

# %% [markdown]
# Write the indexing expression to print *"Data Science and Data Engineering Batch"*

# %%
Python_text = "Edukron Data Science and Data Engineer Batch 2026"
print(Python_text[8:37])
print(Python_text[-41:-12])
# Out:
# Data Science and Data Enginee
# Data Science and Data Enginee
