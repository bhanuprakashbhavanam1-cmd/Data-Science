# %% [markdown]
# # Section 1: Lambda Expressions — 20 Questions

# %% [markdown]
# ### Question 1
# ```python
# number = 8
# ```
# Write a lambda expression to calculate the square of `number`.

# %%
# number =8
# square=(lambda x:x**2)(number)
# print(square)

square=(lambda x:x**2)
number=square(8)
print(number)
# Out:
# 64

# %% [markdown]
# ### Question 2
# ```python
# number = 5
# ```
# Write a lambda expression to calculate the cube of `number`.

# %%
number=5
cube=(lambda x:x**3)(number)
print(cube)
# Out:
# 125

# %% [markdown]
# ### Question 3
# ```python
# a = 25
# b = 17
# ```
# Write a lambda expression to add `a` and `b`.

# %%
add_exp=(lambda x,y:x+y)
add_exp(25,17)
# Out:
# 42

# %% [markdown]
# ### Question 4
# ```python
# a = 50
# b = 18
# ```
# Write a lambda expression to subtract `b` from `a`.

# %%
values=(lambda x,y:x-y)
values(50,18)
# Out:
# 32

# %% [markdown]
# ### Question 5
# ```python
# a = 12
# b = 9
# ```
# Write a lambda expression to multiply `a` and `b`.

# %%
from functools import reduce
values = [12,9]
func=reduce(lambda x,y:x*y,values)
print(func)
# Out:
# 108

# %% [markdown]
# ### Question 6
# ```python
# a = 100
# b = 4
# ```
# Write a lambda expression to divide `a` by `b`.

# %%
values = [100,4]
func=(lambda x,y:x/y)
result=func(*values)  # To pass the list items as separate arguments, use the unpacking operator *
print(result)
# Out:
# 25.0

# %% [markdown]
# ### Question 7
# ```python
# a = 72
# b = 91
# ```
# Write a lambda expression to return the larger number.

# %%
values=[72,91]
func = (lambda x,y:x if x > y else y)
result=func(*values)
print(result)
# Out:
# 91

# %% [markdown]
# ### Question 8
# ```python
# a = 46
# b = 28
# ```
# Write a lambda expression to return the smaller number.

# %%
from functools import reduce
values = [46,28]
func=reduce(lambda x,y:x if x<y else y,values)
print(func)
# Out:
# 28

# %% [markdown]
# ### Question 9
# ```python
# number = 34
# ```
# Write a lambda expression that returns `True` when the number is even and `False` otherwise.

# %%
number=34
func=(lambda x:True if x%2==0 else False)(number)
print(func)
# Out:
# True

# %% [markdown]
# ### Question 10
# ```python
# number = 27
# ```
# Write a lambda expression that returns `True` when the number is odd and `False` otherwise.

# %%
number=27
func=(lambda x:True if x%2!=0 else False)
result=func(number)
print(result)
# Out:
# True

# %% [markdown]
# ### Question 11
# ```python
# length = 12
# width = 8
# ```
# Write a lambda expression to calculate the area of a rectangle.

# %%
length=12
width=8
func=(lambda x,y:x*y)
result=func(length,width)
print(result)
# Out:
# 96

# %% [markdown]
# ### Question 12
# ```python
# radius = 7
# ```
# Write a lambda expression to calculate the area of a circle using `3.14`.

# %%
from functools import reduce
radius=7
pi=3.14
area_of_circle=reduce(lambda x,y:x*(y**2),[pi,radius])
print(area_of_circle)
# Out:
# 153.86

# %% [markdown]
# ### Question 13
# ```python
# length = 15
# width = 10
# ```
# Write a lambda expression to calculate the perimeter of a rectangle.

# %%
from functools import reduce
length = 15
width = 10
perimeter_of_rectangle=reduce(lambda x,y:2*(x+y),[length,width])
print(perimeter_of_rectangle)
# Out:
# 50

# %% [markdown]
# ### Question 14
# ```python
# celsius = 35
# ```
# Write a lambda expression to convert Celsius into Fahrenheit.

# %%
celsius = 35
C_to_F=(lambda x:(x*1.8)+32)(celsius)
print(C_to_F)
# Out:
# 95.0

# %% [markdown]
# ### Question 15
# ```python
# fahrenheit = 104
# ```
# Write a lambda expression to convert Fahrenheit into Celsius.

# %%
fahrenheit = 104
F_to_C=(lambda x:(x-32)/1.8)(fahrenheit)
print(F_to_C)
# Out:
# 40.0

# %% [markdown]
# ### Question 16
# ```python
# word = "Python"
# ```
# Write a lambda expression to return the length of the string.

# %%
word = "Python"
lenth=(lambda x:len(x))(word)
print(lenth)
# Out:
# 6

# %% [markdown]
# ### Question 17
# ```python
# word = "Azure"
# ```
# Write a lambda expression to return the first character of the string.

# %%
word = "Azure"
first=(lambda x:x[0])(word)
print(first)
# Out:
# A

# %% [markdown]
# ### Question 18
# ```python
# word = "Databricks"
# ```
# Write a lambda expression to return the last character of the string.

# %%
word = "Databricks"
last=(lambda x:x[-1])(word)
print(last)
# Out:
# s

# %% [markdown]
# ### Question 19
# ```python
# number = -45
# ```
# Write a lambda expression to return the absolute value of the number without using `abs()`.

# %%
number =-45
absolute_val=(lambda x: -x if x < 0 else x)(number)
print(absolute_val)
# Out:
# 45

# %% [markdown]
# ### Question 20
# ```python
# marks = 72
# ```
# Write a lambda expression that returns:
# - "Distinction" when marks are 75 or above
# - "Pass" when marks are 40 to 74
# - "Fail" when marks are below 40

# %%
marks = 72
expr=(lambda x: "Distinction" if x >= 75 else("Pass" if 40<=x<=74 else "Fail"))(marks)
print(expr)
# Out:
# Pass

# %% [markdown]
# #Section 2: map() — 20 Questions

# %% [markdown]
# ### Question 1
# ```python
# numbers = [1, 2, 3, 4, 5, 6]
# ```
# Using `map()` and a lambda expression, calculate the square of every number.

# %%
number = [1,2,3,4,5,6]
square=list(map(lambda x:x**2,number))
print(square)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# ### Question 2
# ```python
# numbers = [2, 3, 4, 5, 6]
# ```
# Using `map()` and a lambda expression, calculate the cube of every number.

# %%
numbers = [2,3,4,5,6]
cube=list(map(lambda x:x**3,numbers))
print(cube)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# ### Question 3
# ```python
# numbers = [10, 20, 30, 40, 50]
# ```
# Using `map()`, add 5 to every number.

# %%
numbers = [10,20,30,40,50]
func=list(map(lambda x:x+5,numbers))
print(func)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# ### Question 4
# ```python
# numbers = [15, 25, 35, 45, 55]
# ```
# Using `map()`, subtract 10 from every number.

# %%
numbers = [15,25,35,45,55]
sub=list(map(lambda x:x-10,numbers))
print(sub)
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# ### Question 5
# ```python
# numbers = [1, 5, 10, 15, 20]
# ```
# Using `map()`, multiply every number by 100.

# %%
numbers = [1,5,10,15,20]
mult=list(map(lambda x:x*100,numbers))
print(mult)
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# ### Question 6
# ```python
# names = ["ravi", "anil", "meena", "kiran", "sneha"]
# ```
# Using `map()`, convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
uppercase=list(map(lambda x:x.upper(),names))
print(uppercase)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# ### Question 7
# ```python
# names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
# ```
# Using `map()`, convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
lowercase=list(map(lambda x:x.lower(),names))
print(lowercase)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# ### Question 8
# ```python
# names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
# ```
# Using `map()`, convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
title=list(map(lambda x:x.title(),names))
print(title)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# ### Question 9
# ```python
# words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
# ```
# Using `map()`, calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
length=list(map(lambda x:len(x),words))
print(length)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# ### Question 10
# ```python
# words = ["Python", "Azure", "Docker", "Linux", "Spark"]
# ```
# Using `map()`, extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
char=list(map(lambda x:x[0],words))
print(char)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# ### Question 11
# ```python
# words = ["Python", "Azure", "Docker", "Linux", "Spark"]
# ```
# Using `map()`, extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
char=list(map(lambda x:x[-1],words))
print(char)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# ### Question 12
# ```python
# temperatures = [0, 10, 20, 30, 40]
# ```
# Using `map()`, convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [0, 10, 20, 30, 40]
F_to_C=list(map(lambda x:(x/1.8)+32,temperatures))
print(F_to_C)
# Out:
# [32.0, 37.55555555555556, 43.111111111111114, 48.66666666666667, 54.22222222222222]

# %% [markdown]
# ### Question 13
# ```python
# prices = [100, 250, 500, 1000, 2500]
# ```
# Using `map()`, calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]
gst=list(map(lambda x:x*0.18,prices))
print(gst)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# ### Question 14
# ```python
# prices = [100, 250, 500, 1000, 2500]
# ```
# Using `map()`, calculate the final price after adding 18% GST.

# %%
prices = [100, 250, 500, 1000, 2500]
gst=list(map(lambda x:x*0.18+x,prices))
print(gst)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# ### Question 15
# ```python
# decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
# ```
# Using `map()`, round every number to two decimal places.

# %%
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
rou=list(map(lambda x:round(x,2),decimal_numbers))
print(rou)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# ### Question 16
# ```python
# values = [-10, 20, -35, 40, -55, 60]
# ```
# Using `map()`, convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
# absolute_val = list(map(lambda x:abs(x),values))
absolute_val = list(map(lambda x:-x if x<0 else x,values))
print(absolute_val)
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# ### Question 17
# ```python
# numbers = [10, 20, 30, 40, 50]
# ```
# Using `map()`, convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
int_to_string=list(map(lambda x:str(x),numbers))
print(int_to_string)
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# ### Question 18
# ```python
# names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
# ```
# Using `map()`, remove leading and trailing spaces from every name.

# %%
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
spaces=list(map(lambda x:x.strip(),names))
print(spaces)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# ### Question 19
# ```python
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000}
# ]
# ```
# Using `map()`, extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
names=list(map(lambda x:x["name"],employees))
print(names)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# ### Question 20
# ```python
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000}
# ]
# ```
# Using `map()`, create a new list of dictionaries containing:
# - Employee name
# - Original salary
# - Salary after a 10% increment

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
inc=list(map(lambda x:{"name":x["name"], "salary":x["salary"], "salary_increment":x["salary"]*0.10+x["salary"]},employees))
print(inc)
# Out:
# [{'name': 'Rahul', 'salary': 45000, 'salary_increment': 49500.0}, {'name': 'Anil', 'salary': 65000, 'salary_increment': 71500.0}, {'name': 'Sneha', 'salary': 72000, 'salary_increment': 79200.0}, {'name': 'Kiran', 'salary': 82000, 'salary_increment': 90200.0}]

# %% [markdown]
# # Section 3: filter() — 20 Questions

# %% [markdown]
# ### Question 1
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `filter()`, extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even=list(filter(lambda x:x%2==0,numbers))
print(even)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# ### Question 2
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `filter()`, extract all odd numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd=list(filter(lambda x:x%2 !=0,numbers))
print(odd)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# ### Question 3
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `filter()`, extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
num=list(filter(lambda x:x>50,numbers))
print(num)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# ### Question 4
# ```python
# numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
# ```
# Using `filter()`, extract all numbers less than 100.

# %%
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
num=list(filter(lambda x:x<100,numbers))
print(num)
# Out:
# [45, 89, 56, 91, 34]

# %% [markdown]
# ### Question 5
# ```python
# numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
# ```
# Using `filter()`, extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
num=list(filter(lambda x:x>0,numbers))
print(num)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# ### Question 6
# ```python
# numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
# ```
# Using `filter()`, extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
num=list(filter(lambda x:x<0,numbers))
print(num)
# Out:
# [-15, -8, -25]

# %% [markdown]
# ### Question 7
# ```python
# numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
# ```
# Using `filter()`, remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
num=list(filter(lambda x:x!=0,numbers))
print(num)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# ### Question 8
# ```python
# words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
# ```
# Using `filter()`, extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
ext=list(filter(lambda x:len(x)>5,words))
print(ext)
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# ### Question 9
# ```python
# names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
# ```
# Using `filter()`, extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
ext=list(filter(lambda x:x[0]=="A",names))
print(ext)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# ### Question 10
# ```python
# names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
# ```
# Using `filter()`, extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
ext=list(filter(lambda x:x[-1]=="n",names))
print(ext)
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# ### Question 11
# ```python
# numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
# ```
# Using `filter()`, extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
ext=list(filter(lambda x:x%5==0,numbers))
print(ext)
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# ### Question 12
# ```python
# numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
# ```
# Using `filter()`, extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
ext=list(filter(lambda x:x%3==0 or x%5==0,numbers))
print(ext)
# Out:
# [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]

# %% [markdown]
# ### Question 13
# ```python
# words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
# ```
# Using `filter()`, extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindromes = list(filter(lambda x: x == x[::-1], words))
print(palindromes)
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# ### Question 14
# ```python
# emails = [
#     "john@gmail.com",
#     "rahul@yahoo.com",
#     "admin@python.com",
#     "support@azure.org",
#     "sales@company.com"
# ]
# ```
# Using `filter()`, extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]

email=list(filter(lambda x:x.endswith(".com") ,emails))
print(email)
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# ### Question 15
# ```python
# files = [
#     "sales.csv",
#     "employees.xlsx",
#     "products.csv",
#     "report.pdf",
#     "customers.csv",
#     "notes.txt"
# ]
# ```
# Using `filter()`, extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]
ext=list(filter(lambda x:x.endswith(".csv") ,files))
print(ext)
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# ### Question 16
# ```python
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# ```
# Using `filter()`, extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
ext=list(filter(lambda x:x["salary"]>60000,employees))
print(ext)
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# ### Question 17
# ```python
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Sneha", "marks": 79}
# ]
# ```
# Using `filter()`, extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
ext=list(filter(lambda x:x["marks"]>80,students))
print(ext)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# ### Question 18
# ```python
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 0},
#     {"name": "Monitor", "price": 18000, "stock": 8},
#     {"name": "Printer", "price": 12000, "stock": 0}
# ]
# ```
# Using `filter()`, extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
ext=list(filter(lambda x:x["stock"]!=0,products))
print(ext)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# ### Question 19
# ```python
# people = [
#     {"name": "Rahul", "age": 17},
#     {"name": "Anil", "age": 25},
#     {"name": "Sneha", "age": 16},
#     {"name": "Kiran", "age": 32},
#     {"name": "Meena", "age": 18}
# ]
# ```
# Using `filter()`, extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
ext=list(filter(lambda x:x["age"]>=18,people))
print(ext)
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}, {'name': 'Meena', 'age': 18}]

# %% [markdown]
# ### Question 20
# ```python
# employees = [
#     {"name": "Rahul", "department": "IT", "active": True},
#     {"name": "Anil", "department": "HR", "active": True},
#     {"name": "Sneha", "department": "IT", "active": False},
#     {"name": "Kiran", "department": "IT", "active": True},
#     {"name": "Meena", "department": "Sales", "active": True}
# ]
# ```
# Using `filter()`, extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
ext=list(filter(lambda x:x["department"]=="IT" and x["active"]==True,employees))
print(ext)
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True}, {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# # Section 4: reduce() — 20 Questions

# %% [markdown]
# ### Question 1
# ```python
# numbers = [10, 20, 30, 40, 50]
# ```
# Using `reduce()`, calculate the sum of all numbers.

# %%
from functools import reduce
numbers = [10, 20, 30, 40, 50]
sum=reduce(lambda x,y:x+y,numbers)
print(sum)
# Out:
# 150

# %% [markdown]
# ### Question 2
# ```python
# numbers = [2, 3, 4, 5]
# ```
# Using `reduce()`, calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]
sum=reduce(lambda x,y:x*y,numbers)
print(sum)
# Out:
# 120

# %% [markdown]
# ### Question 3
# ```python
# numbers = [45, 12, 89, 34, 67, 91, 28]
# ```
# Using `reduce()`, find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
sum=reduce(lambda x,y: x if x>y else y,numbers)
print(sum)
# Out:
# 91

# %% [markdown]
# ### Question 4
# ```python
# numbers = [45, 12, 89, 34, 67, 91, 28]
# ```
# Using `reduce()`, find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
sum=reduce(lambda x,y: x if x<y else y,numbers)
print(sum)
# Out:
# 12

# %% [markdown]
# ### Question 5
# ```python
# words = ["Python", " ", "is", " ", "powerful"]
# ```
# Using `reduce()`, combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]
sum=reduce(lambda x,y:x+y,words)
print(sum)
# Out:
# Python is powerful

# %% [markdown]
# ### Question 6
# ```python
# words = ["Python", "Azure", "Cloud", "AI"]
# ```
# Using `reduce()`, calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]
sum=reduce(lambda x,y:x+len(y),words,0)
print(sum)
# Out:
# 18

# %% [markdown]
# ### Question 7
# ```python
# number = 6
# numbers = list(range(1, number + 1))
# ```
# Using `reduce()`, calculate the factorial of `number`.

# %%
number = 6
numbers = list(range(1, number + 1))
fac=reduce(lambda x,y:x*y,numbers)
print(fac)
# Out:
# 720

# %% [markdown]
# ### Question 8
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `reduce()`, calculate the sum of only the even numbers. *Do not create a separate filtered list.*

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
sum=reduce(lambda x,y:x+y if y%2==0 else x,numbers,0)
print(sum)
# Out:
# 280

# %% [markdown]
# ### Question 9
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `reduce()`, calculate the sum of only the odd numbers. *Do not create a separate filtered list.*

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
sum=reduce(lambda x,y:x+y if y%2!=0 else x,numbers,0)
print(sum)
# Out:
# 315

# %% [markdown]
# ### Question 10
# ```python
# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
# ```
# Using `reduce()`, find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
longest=reduce(lambda x,y:x if len(x)>len(y) else y,words)
print(longest)
# Out:
# Kubernetes

# %% [markdown]
# ### Question 11
# ```python
# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
# ```
# Using `reduce()`, find the shortest word.

# %%
from functools import reduce
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
longest=reduce(lambda x,y:x if len(x)<len(y) else y,words)
print(longest)
# Out:
# AI

# %% [markdown]
# ### Question 12
# ```python
# salaries = [45000, 65000, 72000, 82000, 55000]
# ```
# Using `reduce()`, calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]
total=reduce(lambda x,y:x+y,salaries)
print(total)
# Out:
# 319000

# %% [markdown]
# ### Question 13
# ```python
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# ```
# Using `reduce()`, calculate the total payroll directly from the dictionaries.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
payroll=(reduce(lambda x,y:x+y["salary"],employees,0))
print(payroll)
# Out:
# 319000

# %% [markdown]
# ### Question 14
# ```python
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# ```
# Using `reduce()`, find the employee with the highest salary.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
high=reduce(lambda x,y:x if x["salary"]>y["salary"] else y,employees)
print(high)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# ### Question 15
# ```python
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Rahul", "marks": 95}
# ]
# ```
# Using `reduce()`, find the student with the highest marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
high=reduce(lambda x,y:x if x["marks"]>y["marks"] else y,students)
print(high)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# ### Question 16
# ```python
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 15},
#     {"name": "Monitor", "price": 18000, "stock": 8}
# ]
# ```
# Using `reduce()`, calculate the total stock quantity.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
total=reduce(lambda x,y:x+y["stock"],products,0)
print(total)
# Out:
# 53

# %% [markdown]
# ### Question 17
# ```python
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 15},
#     {"name": "Monitor", "price": 18000, "stock": 8}
# ]
# ```
# Using `reduce()`, calculate the total inventory value using `price × stock`.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
total=reduce(lambda x,y:x+(y["price"]*y["stock"]),products,0)
print(total)
# Out:
# 456500

# %% [markdown]
# ### Question 18
# ```python
# sales = [12000, 25000, 18000, 45000, 30000, 52000]
# ```
# Using `reduce()`, calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]
total=reduce(lambda x,y:x+y,sales)
print(total)
# Out:
# 182000

# %% [markdown]
# ### Question 19
# ```python
# dictionaries = [
#     {"name": "Rahul"},
#     {"age": 30},
#     {"department": "IT"},
#     {"salary": 65000}
# ]
# ```
# Using `reduce()`, merge all dictionaries into one dictionary.

# %%
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
total=reduce(lambda x,y:x|y,dictionaries)
print(total)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# ### Question 20
# ```python
# numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
# ```
# Using `reduce()`, calculate the sum of unique numbers only. *Do not directly use sum(set(numbers)).*

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
result = reduce(
    lambda acc, x: (acc[0] | {x}, acc[1] + x) if x not in acc[0] else (acc[0], acc[1]),
    numbers,
    (set(), 0)
)

total_unique_sum = result[1]
print(total_unique_sum)
# Out:
# 336

# %% [markdown]
# # Section 5: Combined Lambda, map(), filter(), and reduce() — 20 Questions

# %% [markdown]
# ### Question 1
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `filter()` and `map()`:
# 1. Extract all even numbers.
# 2. Calculate the square of every even number.
# 3. Return the squared values as a list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result=list(map(lambda x:x**2,filter(lambda x:x%2==0,numbers)))
print(result)
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# ### Question 2
# ```python
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# ```
# Using `filter()` and `reduce()`:
# 1. Extract all odd numbers.
# 2. Calculate their total sum.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result=reduce(lambda x,y:x+y,filter(lambda x:x%2!=0,numbers))
print(result)
# Out:
# 315

# %% [markdown]
# ### Question 3
# ```python
# numbers = [10, 25, 40, 55, 70, 85, 100]
# ```
# Using `filter()` and `map()`:
# 1. Extract numbers greater than 50.
# 2. Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
result=list(map(lambda x:x*2,filter(lambda x:x>50,numbers)))
print(result)
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# ### Question 4
# ```python
# numbers = [-15, 20, -35, 40, 50, -10, 60]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract positive numbers.
# 2. Calculate the square of every positive number.
# 3. Calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]
result=reduce(lambda x,y:x+y,map(lambda x:x**2,filter(lambda x:x>0,numbers)))
print(result)
# Out:
# 8100

# %% [markdown]
# ### Question 5
# ```python
# words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
# ```
# Using `filter()` and `map()`:
# 1. Extract words containing more than five characters.
# 2. Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
result=list(filter(lambda x:len(x)>5,map(lambda x:x.upper(),words)))
print(result)
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# ### Question 6
# ```python
# names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
# ```
# Using `filter()` and `map()`:
# 1. Extract names beginning with "A".
# 2. Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
result=list(map(lambda x:x.lower(),filter(lambda x:x[0]=="A",names)))
print(result)
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# ### Question 7
# ```python
# numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
# ```
# Using `filter()` and `reduce()`:
# 1. Extract numbers divisible by both 3 and 5.
# 2. Calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
result=reduce(lambda x,y:x+y,filter(lambda x:x%3==0 and x%5==0,numbers))
print(result)
# Out:
# 225

# %% [markdown]
# ### Question 8
# ```python
# words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
# ```
# Using `filter()` and `reduce()`:
# 1. Extract palindrome words.
# 2. Join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
result=reduce(lambda x,y:x+"|"+y,filter(lambda x: x==x[::-1],words))
print(result)
# Out:
# madam|level|radar|civic

# %% [markdown]
# ### Question 9
# ```python
# temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract temperatures greater than 30°C.
# 2. Convert the selected values into Fahrenheit.
# 3. Calculate the average Fahrenheit temperature.

# %%
from functools import reduce
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
result=reduce(lambda x,y:x+y,map(lambda x:(x/1.8)+32,filter(lambda x:x>30,temperatures)))/len(list(filter(lambda x: x > 30, temperatures)))
print(result)
# Out:
# 52.83333333333333

# %% [markdown]
# ### Question 10
# ```python
# prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract prices greater than 1000.
# 2. Apply a 10% discount to every selected price.
# 3. Calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
result=reduce(lambda x,y:x+y, map(lambda x:x*0.10, filter(lambda x:x>1000,prices)))
print(result)
# Out:
# 1770.0

# %% [markdown]
# ### Question 11
# ```python
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000},
#     {"id": 105, "name": "Meena", "salary": 55000}
# ]
# ```
# Using `filter()` and `map()`:
# 1. Extract employees earning more than 60000.
# 2. Increase their salary by 10%.
# 3. Return their names and updated salaries.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil",  "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
sainath=list(map(lambda x:(x["name"],x["salary"]*0.10+x["salary"]),filter(lambda x: x["salary"] > 60000 ,employees)))
print(sainath)
# Out:
# [('Anil', 71500.0), ('Sneha', 79200.0), ('Kiran', 90200.0)]

# %% [markdown]
# ### Question 12
# ```python
# employees = [
#     {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
#     {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
#     {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
#     {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
#     {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
# ]
# ```
# Using `filter()` and `reduce()`:
# 1. Extract employees from the IT department.
# 2. Calculate the total salary of IT employees.

# %%
from functools import reduce
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]

result=reduce(lambda x,y:x+y["salary"],filter(lambda x:x["department"]=="IT",employees),0)
print(result)
# Out:
# 199000

# %% [markdown]
# ### Question 13
# ```python
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
#     {"id": 102, "name": "Anil", "salary": 65000, "active": True},
#     {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
#     {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
#     {"id": 105, "name": "Meena", "salary": 55000, "active": True},
#     {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
# ]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract active employees.
# 2. Increase every active employee's salary by 15%.
# 3. Calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]

result=reduce(lambda x,y:x+y,map(lambda x:x["salary"]*0.15+x["salary"],filter(lambda x:x["active"]==True,employees)))
print(result)
# Out:
# 284050.0

# %% [markdown]
# ### Question 14
# ```python
# students = [
#     {"name": "Ravi", "marks": 92, "passed": True},
#     {"name": "Kiran", "marks": 68, "passed": True},
#     {"name": "Meena", "marks": 85, "passed": True},
#     {"name": "Ajay", "marks": 48, "passed": True},
#     {"name": "Sneha", "marks": 35, "passed": False},
#     {"name": "Rahul", "marks": 95, "passed": True}
# ]
# ```
# Using `filter()` and `reduce()`:
# 1. Extract students who passed.
# 2. Find the topper among the passed students.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]

result=reduce(lambda x,y:x if x["marks"]>y["marks"] else y,filter(lambda x:x["passed"]==True,students))
print(result)
# Out:
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# ### Question 15
# ```python
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Sneha", "marks": 79},
#     {"name": "Rahul", "marks": 95}
# ]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract students scoring more than 70.
# 2. Extract only their marks.
# 3. Calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]

result=reduce(lambda x,y:x+y,map(lambda x:x["marks"],filter(lambda x:x["marks"]>70,students)))/len(list(filter(lambda x:x["marks"]>70,students)))
print(result)
# Out:
# 87.75

# %% [markdown]
# ### Question 16
# ```python
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 0},
#     {"name": "Monitor", "price": 18000, "stock": 8},
#     {"name": "Printer", "price": 12000, "stock": 0},
#     {"name": "SSD", "price": 6500, "stock": 12}
# ]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract products currently in stock.
# 2. Calculate each product's inventory value using `price × stock`.
# 3. Calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]

result=reduce(lambda x,y:x+y,map(lambda x:x["price"]*x["stock"],filter(lambda x:x["stock"]>0,products)))
print(result)
# Out:
# 512000

# %% [markdown]
# ### Question 17
# ```python
# products = [
#     {"name": "Laptop", "price": 55000, "category": "Electronics"},
#     {"name": "Chair", "price": 4500, "category": "Furniture"},
#     {"name": "Monitor", "price": 18000, "category": "Electronics"},
#     {"name": "Desk", "price": 8500, "category": "Furniture"},
#     {"name": "SSD", "price": 6500, "category": "Electronics"}
# ]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract products belonging to the Electronics category.
# 2. Apply a 20% discount.
# 3. Calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]

result=list(map(lambda x:x["price"]-x["price"]*0.20,filter(lambda x:x["category"]=="Electronics",products)))
print(result)
# Out:
# [44000.0, 14400.0, 5200.0]

# %% [markdown]
# ### Question 18
# ```python
# orders = [
#     {"order_id": 1001, "amount": 1200, "status": "Delivered"},
#     {"order_id": 1002, "amount": 3500, "status": "Pending"},
#     {"order_id": 1003, "amount": 8500, "status": "Delivered"},
#     {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
#     {"order_id": 1005, "amount": 7600, "status": "Delivered"},
#     {"order_id": 1006, "amount": 5100, "status": "Pending"}
# ]
# ```
# Using `filter()` and `reduce()`:
# 1. Extract delivered orders.
# 2. Calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]

result = reduce(lambda x,y:x+y["amount"],filter(lambda x:x["status"]=="Delivered",orders),0)
print(result)
# Out:
# 17300

# %% [markdown]
# ### Question 19
# ```python
# transactions = [
#     {"id": 1, "amount": 1200},
#     {"id": 2, "amount": 5200},
#     {"id": 3, "amount": 18000},
#     {"id": 4, "amount": 2500},
#     {"id": 5, "amount": 9600},
#     {"id": 6, "amount": 7200}
# ]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract transactions whose amount is greater than 5000.
# 2. Add 18% GST to every selected transaction.
# 3. Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]

result = reduce(lambda x,y:x+y,map(lambda x:x["amount"]*0.18+x["amount"],filter(lambda x:x["amount"]>5000,transactions)))
print(result)
# Out:
# 47200.0

# %% [markdown]
# ### Question 20
# ```python
# sales_records = [
#     {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
#     {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
#     {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
#     {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
#     {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
#     {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
# ]
# ```
# Using `filter()`, `map()`, and `reduce()`:
# 1. Extract active salespeople from the South region.
# 2. Calculate a 5% incentive for each selected salesperson.
# 3. Create a list containing salesperson name, sales amount, and incentive.
# 4. Calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
result = reduce(lambda x,y:x+y["incentive"],map(lambda x:{"name":x["salesperson"],"sales amount":x["sales"],"incentive":x["sales"]*0.5},filter(lambda x:(x["active"]==True and x["region"]=="South"),sales_records)),0)
print(result)
# Out:
# 112500.0
